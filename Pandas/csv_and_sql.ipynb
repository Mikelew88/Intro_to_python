# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/MikeLewis/Downloads/brand_spark_invites.xlsx')

# %%
for i, row in df.iterrows():
    print(i)
    print(type(row))
    print(row)
# Out:
# Banza Spaghetti
# <class 'pandas.core.series.Series'>
# Target Needed    2.800000e+01
# invites          8.400000e+01
# UPC Codes        8.571830e+11
# Unnamed: 3                NaN
# Unnamed: 4                NaN
# Unnamed: 5                NaN
# Unnamed: 6                NaN
# Unnamed: 7                NaN
# Unnamed: 8                NaN
# Unnamed: 9                NaN
# Unnamed: 10               NaN
# Unnamed: 11               NaN
# Unnamed: 12               NaN
# Unnamed: 13               NaN
# Unnamed: 14               NaN
# Unnamed: 15               NaN
# Name: Banza Spaghetti, dtype: float64
# c2o Pure Coconut Water with Pineapple Juice & Coconut Pulp
# <class 'pandas.core.series.Series'>
# Target Needed    3.500000e+01
# invites          1.050000e+02
# UPC Codes        8.538830e+11
# Unnamed: 3       8.538830e+11
# Unnamed: 4                NaN
# Unnamed: 5                NaN
# Unnamed: 6                NaN
# Unnamed: 7                NaN
# Unnamed: 8                NaN
# ...
